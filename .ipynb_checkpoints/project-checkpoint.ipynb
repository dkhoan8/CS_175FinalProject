# %%
import sys
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
matplotlib.use('Agg')

from Model import classification_head
from numpy import array
from PIL import ImageOps, Image

WEIGHTS_FILE = "classifier.ckpt"
SIZE = (32,32)

def detect_single(img_path, saved_model_weights,sess):
    X = tf.placeholder(tf.float32, shape=(1, 32, 32, 3))
    prediction = tf.nn.softmax(classification_head(X))

    pix = np.array(img_path)
    norm_img = (255-pix)*1.0/255.0
    exp = np.expand_dims(norm_img, axis=0)

    feed_dat = {X: exp}
    predictions = sess.run(prediction, feed_dict=feed_dat)
    # print("Best Prediction is:", np.argmax(predictions))
    return np.argmax(predictions), pix

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import glob

image_list = []
saved_model_weights = WEIGHTS_FILE
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, saved_model_weights)
    for filename in glob.glob('Single_Digit_Test/*.png'):
        print("==================================================================================================")
        print("==================================================================================================")
        im=Image.open(filename)
        image_list.append(im)
        im = im.resize(SIZE, Image.ANTIALIAS)
        
        quality_val = 90
        im.save(filename, 'PNG', quality=quality_val)
        
        prediction, test_img = detect_single(im, saved_model_weights,sess)
        plt.figure()
        imgplot = plt.imshow(test_img)
        plt.show()
        print("BEST PREDICTION IS:", prediction)
        print("==================================================================================================")
        print("==================================================================================================")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# INFO:tensorflow:Restoring parameters from classifier.ckpt
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 0
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 6
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 4
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 2
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 8
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# Not using dropout
# BEST PREDICTION IS: 6
# ==================================================================================================
# ==================================================================================================

# %%
import matplotlib
matplotlib.use('Agg')

import sys
import os
import numpy as np
import tensorflow as tf
import PIL.Image as Image
import matplotlib.pyplot as plt
import time

from Model import regression_head
from svhn_data import load_svhn_data
from PIL import ImageOps, Image
from tensorflow.python.saved_model import tag_constants
from six.moves import cPickle as pickle
from six.moves import range

WEIGHTS_FILE = "regression.ckpt"
SIZE = (64,64)

def formatNum(pred_array):
    pred_str = ""
    for i in range(len(pred_array)):
        if pred_array[i] != 10:
            pred_str += str(pred_array[i])
        else:
            return pred_str
    return pred_str


def detect_multi(img_path, saved_model_weights ,session):

    print("-------------------Attemped resize img------------------------------")    
    fit_and_resized_image = ImageOps.fit(img_path, SIZE, Image.ANTIALIAS)
    pix = np.array(fit_and_resized_image)
    norm_pix = (255-pix)*1.0/255.0
    exp = np.expand_dims(norm_pix, axis=0)

    X = tf.placeholder(tf.float32, shape=(1, 64, 64, 3))
    [logits_1, logits_2, logits_3, logits_4, logits_5] = regression_head(X)

    predict = tf.stack([tf.nn.softmax(logits_1),
                      tf.nn.softmax(logits_2),
                      tf.nn.softmax(logits_3),
                      tf.nn.softmax(logits_4),
                      tf.nn.softmax(logits_5)])

    best_prediction = tf.transpose(tf.argmax(predict, 2))
    feed_dict = {X: exp}
    start_time = time.time()
    predictions = session.run(best_prediction, feed_dict=feed_dict)
    pred = formatNum(predictions[0])
    end_time = time.time()
    return pred, pix

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import glob

WEIGHT_FILE = "regression.ckpt"
image_list = []
saved_model_weights = WEIGHTS_FILE

saver = tf.train.Saver()
with tf.Session() as session:
    saver.restore(session, "regression.ckpt")
    for filename in glob.glob('Multi_Digit_Test/*.png'):
        print("==================================================================================================")
        print("==================================================================================================")
        im=Image.open(filename)
        image_list.append(im)
        prediction, test_img = detect_multi(im, saved_model_weights,session)
        plt.figure()
        imgplot = plt.imshow(test_img)
        plt.show()
        print("BEST PREDICTION IS:", prediction)
        print("==================================================================================================")
        print("==================================================================================================")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# INFO:tensorflow:Restoring parameters from regression.ckpt
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 104
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 63
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 165
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 104
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 14
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 14
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 31
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 2
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 30
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 9
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 68
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 81
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 17
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 10
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 12
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 513
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 18
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 103
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 16
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 51
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 35
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 6
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 61
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 108
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 42
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 58
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 16
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 24
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 79
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 55
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 222
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 23
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 2
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 41
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 401
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 24
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 16
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 51
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 112
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 2
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 3
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 133
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 14
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 12
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 111
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 17
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 20
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 122
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 211
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 89
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 204
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 521
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 34
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 46
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 17
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 31
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 163
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 9
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 15
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 33
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 178
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 7
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 56
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 60
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 47
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 355
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 32
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 143
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 29
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 58
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 13
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 10
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 114
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 181
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 31
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 38
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 15
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 33
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 18
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 106
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 134
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 121
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 144
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 79
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 45
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 1
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 31
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 17
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 5
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 11
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 128
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 164
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 104
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 35
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 177
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 42
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 127
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 18
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 36
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 120
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# ==================================================================================================
# -------------------Attemped resize img------------------------------
# BEST PREDICTION IS: 2
# ==================================================================================================
# ==================================================================================================
